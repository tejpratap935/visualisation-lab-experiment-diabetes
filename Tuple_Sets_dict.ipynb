# %% [markdown]
# #tuple
# ##ordered
# ##indexed
# ##immutable
# ## ()

# %%
ages =(22, 38, 26, 35)
print(type(ages))
print(ages)
student = (101,"tej")
print(type(student))
print(student)
# Out:
# <class 'tuple'>
# (22, 38, 26, 35)
# <class 'tuple'>
# (101, 'tej')

# %%
mt_tuple=()

# %%
print(mt_tuple)
print(type(mt_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
single_tuple=("hello",)
single_tuple=(10,)
print(single_tuple)
print(type(single_tuple))
# Out:
# (10,)
# <class 'tuple'>

# %%
print(student)
# Out:
# (101, 'tej')

# %%
print(student[0])
# Out:
# 101

# %%
print(student[-1])
# Out:
# tej

# %%
print(student[1:3])
# Out:
# ('tej',)

# %%
student=(101,"tej",22)
print(student)
# Out:
# (101, 'tej', 22)

# %%
t1=(1,2)
t2=(3,4)
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4)

# %%
del t3
print(t3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2302/3711359676.py in <cell line: 0>()
#       1 del t3
# ----> 2 print(t3)
#
# NameError: name 't3' is not defined

# %%
text ="hello"
print(tuple(text))

# %%
lst =[10,20,30,40]
t=tuple(lst)
print(t)
print(type(t))
# Out:
# (10, 20, 30, 40)
# <class 'tuple'>

# %%
print (t)
print(type(t))
lst1=list(t)
print(lst1)
print(type(lst1))
# Out:
# (10, 20, 30, 40)
# <class 'tuple'>
# [10, 20, 30, 40]
# <class 'list'>

# %%
val =(10,20,30,40,20)
print(len(val))
# Out:
# 5

# %%
print(val.count(10))
# Out:
# 1

# %%
print(val.index(30))
# Out:
# 2

# %%
print(10 not in val)
# Out:
# False

# %%
print(20 in val)
# Out:
# True

# %%
t =(10,20,30,40,50)
print(t[1:4])
# Out:
# (20, 30, 40)

# %%
print(t[:3])
# Out:
# (10, 20, 30)

# %%
print(t[2:])
# Out:
# (30, 40, 50)

# %%
print(t[::-1])
# Out:
# (50, 40, 30, 20, 10)

# %%
print(t)
print(t[:])
print(t[::-1])
print(t[::2])
print(t[1::2])
# Out:
# (10, 20, 30, 40)
# (10, 20, 30, 40)
# (40, 30, 20, 10)
# (10, 30)
# (20, 40)

# %%
print(t*3)
# Out:
# (10, 20, 30, 40, 10, 20, 30, 40, 10, 20, 30, 40)

# %%
print(min(t))
print(max(t))
print(sum(t))
# Out:
# 10
# 40
# 100

# %%
print(sorted(t))

print(sorted(t, reverse= True))
# Out:
# [10, 20, 30, 40]
# [40, 30, 20, 10]

# %%
student = ("chhavi", 20, "B.tech", "cse")
(name, age, course ,branch)= student
(name, age, *details) = student
print(name)
print(age)
print(course)
print(branch)
print(details)
# Out:
# chhavi
# 20
# B.tech
# cse
# ['B.tech', 'cse']

# %%
student = ("chhavi", 20, "B.tech", "cse")
(name, age, course ,branch)= student
(name, age, *details, branch) = student
print(name)
print(age)
print(course)
print(branch)
print(details)
# Out:
# chhavi
# 20
# B.tech
# cse
# ['B.tech']

# %%
t =((1,2),(3,4),(5,6))
print(t[0])
print(t[1][1])
print(t[-1][-1])
# Out:
# (1, 2)
# 4
# 6

# %%
t1=(10,20,30)
t2=(10,20,40)
print(t1==t2)
print(t1<t2)
# Out:
# False
# True

# %%
t = (10,20,30,40,50)
for x in t:
  print(x)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
for i, value in enumerate(t):
  print(value, i)
# Out:
# 10 0
# 20 1
# 30 2
# 40 3
# 50 4

# %%
for i, value in enumerate(t):
  print( i, value)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50

# %%
t=(10,[20,30],40)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t[1].append(50)
print(t)
# Out:
# (10, [20, 30, 50], 40)

# %% [markdown]
# #sets
# #unordered
# #unique element
# #remove duplicate and comparing groups

# %%
cities ={"Delhi", "Agra"}
print(cities)
print(type(cities))
# Out:
# {'Agra', 'Delhi'}
# <class 'set'>

# %%
cities.add("Mathura")
print(cities)
cities.update(["Lucknow","Kanpur"])
print(cities)
# Out:
# {'Agra', 'Mathura', 'Delhi'}
# {'Mathura', 'Lucknow', 'Agra', 'Kanpur', 'Delhi'}

# %%
cities.remove("Agra")

# %%
print(cities)
cities.discard("Lucknow")
print(cities)
# Out:
# {'Mathura', 'Lucknow', 'Kanpur', 'Delhi'}
# {'Mathura', 'Kanpur', 'Delhi'}

# %%
cities.remove("Agra")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2302/3909120295.py in <cell line: 0>()
# ----> 1 cities.remove("Agra")
#
# KeyError: 'Agra'

# %%
cities.discard("Agra")

# %%
cities.remove("delhi")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2302/310068030.py in <cell line: 0>()
# ----> 1 cities.remove("delhi")
#
# KeyError: 'delhi'

# %%
cities.discard("delhi")

# %%
print(cities)
rem = cities.pop()
print(rem)
print(cities)
# Out:
# {'Mathura', 'Kanpur', 'Delhi'}
# Mathura
# {'Kanpur', 'Delhi'}

# %%
cities.update(["Lucknow","Kanpur"])
print(cities)
print(cities)
rem = cities.pop()
print(rem)
print(cities)
# Out:
# {'Lucknow', 'Kanpur', 'Delhi'}
# {'Lucknow', 'Kanpur', 'Delhi'}
# Lucknow
# {'Kanpur', 'Delhi'}

# %%
cities.discard("Agra")

# %%
cities.clear()
print(cities)
# Out:
# set()

# %%
A = {"Delhi","Agra","Lucknow"}
B= {"Agra","Delhi","Mathura"}
print(A|B)
# Out:
# {'Lucknow', 'Mathura', 'Agra', 'Delhi'}

# %%
print(A.union(B))
# Out:
# {'Lucknow', 'Mathura', 'Agra', 'Delhi'}

# %%
print(A^B)
# Out:
# {'Mathura', 'Lucknow'}

# %%
print(A&B)
# Out:
# {'Agra', 'Delhi'}

# %%
print(A-B)
# Out:
# {'Lucknow'}

# %% [markdown]
# #Dictionaries
# #key:value

# %%
student={"name":"Shika","Age":19,"branch":"CSE"}
print(type(student))
print(student)
mt_dict ={}
print(type(mt_dict))
print(mt_dict)
# Out:
# <class 'dict'>
# {'name': 'Shika', 'Age': 19, 'branch': 'CSE'}
# <class 'dict'>
# {}

# %%
print(student["name"])
print(student["Age"])
# Out:
# Shika
# 19

# %%
print(student.get("name"))
print(student.get("city"))
print(student.get("city", "not available"))
# Out:
# Shika
# None
# not available

# %%
student["semester"]=3
student["city"]="Mathura"
student["Age"]= 20
print(student)
# Out:
# {'name': 'Shika', 'Age': 20, 'branch': 'CSE', 'semester': 3, 'city': 'Mathura'}

# %%
student.update({"Age":23, "semester":5, "grade":A})
print(student)
# Out:
# {'name': 'Shika', 'Age': 23, 'branch': 'CSE', 'semester': 5, 'city': 'Mathura', 'grade': {'Lucknow', 'Agra', 'Delhi'}}

# %%
age= student.pop("Age")
print(age)
print(student)
# Out:
# 23
# {'name': 'Shika', 'branch': 'CSE', 'semester': 5, 'city': 'Mathura', 'grade': {'Lucknow', 'Agra', 'Delhi'}}

# %%
item = student.popitem()
print(item)
print(student)
# Out:
# ('grade', {'Lucknow', 'Agra', 'Delhi'})
# {'name': 'Shika', 'branch': 'CSE', 'semester': 5, 'city': 'Mathura'}

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'branch', 'semester'])

# %%
del student["city"]
print(student)
# Out:
# {'name': 'Shika', 'branch': 'CSE', 'semester': 5}

# %%
print(student.values())
# Out:
# dict_values(['Shika', 'CSE', 5])

# %%
print(student.items())
# Out:
# dict_items([('name', 'Shika'), ('branch', 'CSE'), ('semester', 5)])

# %%
for key, value in student.items():
  print(key, value)
# Out:
# name Shika
# branch CSE
# semester 5

# %%
data={
    "Name":["Yogesh","Chhavi","shikha"],
    "Age":[21,22,28],
    "Fare":[50,70,40]
}
print(data)
# Out:
# {'Name': ['Yogesh', 'Chhavi', 'shikha'], 'Age': [21, 22, 28], 'Fare': [50, 70, 40]}

# %%
import pandas as pd
df= pd.DataFrame(data)
print(df)
# Out:
#      Name  Age  Fare
# 0  Yogesh   21    50
# 1  Chhavi   22    70
# 2  shikha   28    40

# %% [markdown]
# write a program for paas fail classify age using if else and else
# claasify fair
# list
# create 5 name add insert update and remove items find length max min and total
# tupple create tupple of ages access its element attempt andupdate and combine 2 couples
# set
# remove duplica
# create dictionary display name age fare and family size update age and delete fair
# create a list of passenger dictionary use if to print adult passengers create dictionary of name age pair list and convert into data phase
